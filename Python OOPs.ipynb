# %% [markdown]
# # Python OOPs Questions

# %% [markdown]
# ## 1. What is Object-Oriented Programming (OOP)
# Ans - Object Oriented Programming (OOP)  is a way of writing programs by creating classes and objects. It helps developers organize code so it is reusable, easy to maintain, and connected to real world concepts.

# %% [markdown]
# ## 2. What is a class in OOP
# Ans - A class in OOP is a blueprint or template used to create objects. It defines the properties (variables) and behaviors (methods) that the objects created from it will have.

# %% [markdown]
# ## 3.What is an object in OOP
# Ans - An object in OOP is a real instance of a class. While a class is just a blueprint, an object contains actual data and can perform actions defined in the class.
#
# Once an object is created, it occupies memory and can use the attributes and methods of its class.

# %% [markdown]
# ## 4. What is the difference between abstraction and encapsulation
# Ans -
# | Feature | Abstraction | Encapsulation |
# |--------|-------------|---------------|
# | Meaning | Hides unnecessary details and shows only essential features | Wraps data and methods together and protects the data |
# | Focus | What the object does | How the object does it and how data is accessed |
# | Purpose | Reduce complexity for the user | Secure and control access to data |
# | Implementation | Using abstract classes, interfaces, or abstract methods | Using access modifiers, getters and setters |
# | Example | TV remote shows functions but hides internal working | Bank account hides balance and allows access through deposit/withdraw methods |

# %% [markdown]
# ## 5.What are dunder methods in Python
# Ans - Dunder methods in Python are special built-in methods whose names start and end with double underscores. They are also called magic methods. These methods allow classes to behave like built-in types and let you customize how objects respond to operators, functions or built-in behaviors.

# %% [markdown]
# ## 6  Explain the concept of inheritance in OOP
# Ans - Inheritance in OOP means creating a new class using the features of an existing class. The new class (called the child or derived class) automatically gets the properties and methods of the existing class (called the parent or base class). This helps reuse code and avoids writing the same logic again.

# %% [markdown]
# ## 7. What is polymorphism in OOP
# Ans - Polymorphism in OOP means the same function or method name can behave differently depending on the object or context. It allows one action to have many forms.

# %% [markdown]
# ## 8 How is encapsulation achieved in Python
# Ans - ChatGPT said:
#
# Encapsulation in Python is achieved by restricting direct access to variables and controlling it through methods. This is usually done using access modifiers, especially private and protected attributes.

# %% [markdown]
# ## 9 What is a constructor in Python
# Ans - A constructor in Python is a special method that runs automatically when an object is created. Its main purpose is to initialize (assign) values to the object's attributes.
#
# In Python, the constructor method is named __init__().

# %% [markdown]
# ## 10. What are class and static methods in Python
# Ans - Class methods and static methods are two special types of methods in Python that are defined inside a class but work differently from regular instance methods.

# %% [markdown]
# ## 11. What is method overloading in Python
# Ans - Method overloading means having multiple methods with the same name but different numbers or types of parameters. Many languages like Java and C++ support it directly, but Python does not allow true method overloading in the same way.
#
# In Python, if you define two methods with the same name in a class, the last one will overwrite the earlier one.

# %% [markdown]
# ## 12. What is method overriding in OOP
# Ans - Method overriding in OOP happens when a child class provides its own version of a method that already exists in the parent class. The method name and parameters remain the same, but the behavior changes based on the class using it.

# %% [markdown]
# ## 13.What is a property decorator in Python
# Ans - A property decorator in Python is used to turn a method into an attribute. It lets you access a method like a normal variable without using parentheses. This is helpful when you want controlled access to a variable, especially when using getters and setters.

# %% [markdown]
# ## 14.Why is polymorphism important in OOP
# Ans - Polymorphism is important in OOP because it makes code flexible, reusable and easier to maintain. It allows one function or method name to work differently based on the object calling it. This means you can write general code that works with many object types instead of rewriting the same logic again.

# %% [markdown]
# ## 15. What is an abstract class in Python
# Ans - An abstract class in Python is a class that cannot be instantiated directly and is meant to act as a base for other classes. It defines a structure for subclasses and may contain one or more abstract methods. An abstract method is a method that is declared but doesn’t have a complete implementation in the base class.

# %% [markdown]
# ## 16.What are the advantages of OOP
# Ans -
#
#
# | Advantage           |  Description                                     |
# | ------------------- | ----------------------------------------------------- |
# | Reusability         | Code can be used again using classes and inheritance  |
# | Maintenance         | Easy to modify and update code                        |
# | Security            | Data is protected using encapsulation                 |
# | Scalability         | Program can grow without breaking existing code       |
# | Real-world modeling | Works with real-life concepts in code                 |
# | Flexibility         | Polymorphism allows one interface with multiple forms |

# %% [markdown]
# ## 17.What is the difference between a class variable and an instance variable
# Ans -
#
# | Feature       | Class Variable        | Instance Variable                   |
# | ------------- | --------------------- | ----------------------------------- |
# | Belongs to    | The class             | A specific object                   |
# | Memory        | Shared by all objects | Separate for each object            |
# | Change effect | Affects every object  | Affects only that object            |
# | Defined in    | Class body            | Inside methods (usually `__init__`) |

# %% [markdown]
# ## 18. What is multiple inheritance in Python
# Ans - Multiple inheritance in Python means a class can inherit features from more than one parent class. In simple terms, a single child class can have multiple base classes.

# %% [markdown]
# ## 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in PythonH
# Ans - __str__ and __repr__ are two special (dunder) methods in Python used to define how an object should be represented as text. They help make objects easier to understand when printed or inspected.

# %% [markdown]
# ## 20. What is the significance of the ‘super()’ function in Python
# Ans - super() is used to access and reuse parent class methods in a child class. It makes inheritance cleaner, avoids duplication and works smoothly when multiple classes are involved.

# %% [markdown]
# ## 21. What is the significance of the __del__ method in Python
# Ans - The __del__ method in Python is a special method called when an object is about to be destroyed. It acts like a destructor. Python automatically handles memory management, so you rarely need it, but it's useful when you want to clean up resources before the object is removed from memory.

# %% [markdown]
# ## 22.What is the difference between @staticmethod and @classmethod in Python
# Ans -
# | Feature | @staticmethod | @classmethod |
# |--------|---------------|--------------|
# | First parameter | None | `cls` |
# | Access instance variables | No | No |
# | Access class variables | No | Yes |
# | Can modify class state | No | Yes |
# | Typical use | Utility or helper functions | Methods that work with or modify class-level data |
# | Call using | Class name or object | Class name or object |

# %% [markdown]
# ## 23. How does polymorphism work in Python with inheritance
# Ans - Polymorphism with inheritance in Python works by allowing a child class to override a method from the parent class, and then using the same method name to perform different actions depending on the object calling it. Even though the method name is the same, Python decides which version to run based on the object type.

# %% [markdown]
# ## 24.What is method chaining in Python OOP
# Ans - Method chaining in Python OOP means calling multiple methods on the same object in a single line by returning the object itself from each method. For method chaining to work, each method must return self.

# %% [markdown]
# ## 25. What is the purpose of the __call__ method in Python?
# Ans -
# The __call__ method in Python allows an object to be called like a function. When you define __call__ inside a class, instances of that class become callable, meaning you can use parentheses () after the object name.

# %% [markdown]
# # Practical Questions

# %% [markdown]
# ## 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:  # parent class
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):  # child class
    def speak(self):
        print("Bark!")

# creating objects
a = Animal()
d = Dog()

a.speak()
d.speak()
# Out:
# Animal makes a sound
# Bark!

# %% [markdown]
# ## 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):  # abstract parent class
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):  # child class
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):  # child class
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# creating objects
c = Circle(5)
r = Rectangle(4, 6)

print("Area of Circle:", c.area())
print("Area of Rectangle:", r.area())
# Out:
# Area of Circle: 78.5
# Area of Rectangle: 24

# %% [markdown]
# ## 3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:   # Parent class
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

class Car(Vehicle):   # Child class inheriting from Vehicle
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

class ElectricCar(Car):   # Child class inheriting from Car
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

# Creating object of ElectricCar
e_car = ElectricCar("Four-wheeler", "Tesla", "75 kWh")

print("Vehicle Type:", e_car.vehicle_type)
print("Brand:", e_car.brand)
print("Battery Capacity:", e_car.battery_capacity)
# Out:
# Vehicle Type: Four-wheeler
# Brand: Tesla
# Battery Capacity: 75 kWh

# %% [markdown]
# ## 4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:  # base class
    def fly(self):
        print("Birds can fly")

class Sparrow(Bird):  # derived class
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):  # derived class
    def fly(self):
        print("Penguins cannot fly")

# function demonstrating polymorphism
def show_flying(bird):
    bird.fly()

# creating objects
s = Sparrow()
p = Penguin()

show_flying(s)
show_flying(p)
# Out:
# Sparrow flies high
# Penguins cannot fly

# %% [markdown]
# ## 5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

# %%
class BankAccount:
    def __init__(self, initial_balance=0):
        self.__balance = initial_balance  # private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount")

    def check_balance(self):
        print(f"Current Balance: {self.__balance}")

# creating an object
account = BankAccount(1000)

account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Deposited: 500
# Withdrawn: 300
# Current Balance: 1200

# %% [markdown]
# ## 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().

# %%
class Instrument:  # base class
    def play(self):
        print("Instrument is being played")

class Guitar(Instrument):  # derived class
    def play(self):
        print("Playing the guitar")

class Piano(Instrument):  # derived class
    def play(self):
        print("Playing the piano")

# function demonstrating polymorphism
def start_playing(instrument):
    instrument.play()

# creating objects
g = Guitar()
p = Piano()

start_playing(g)
start_playing(p)
# Out:
# Playing the guitar
# Playing the piano

# %% [markdown]
# ## 7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# using the methods
print("Addition:", MathOperations.add_numbers(10, 5))
print("Subtraction:", MathOperations.subtract_numbers(10, 5))
# Out:
# Addition: 15
# Subtraction: 5

# %% [markdown]
# ## 8. Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0  # class variable

    def __init__(self, name):
        self.name = name
        Person.count += 1  # increment whenever a new object is created

    @classmethod
    def total_persons(cls):
        return cls.count


# creating objects
p1 = Person("Aman")
p2 = Person("Riya")
p3 = Person("Karan")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# ## 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# creating objects
f1 = Fraction(3, 4)
f2 = Fraction(5, 8)

print(f1)
print(f2)
# Out:
# 3/4
# 5/8

# %% [markdown]
# ## 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):  # operator overloading for +
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"


# creating objects
v1 = Vector(3, 4)
v2 = Vector(1, 2)

# using overloaded +
v3 = v1 + v2

print("Vector 1:", v1)
print("Vector 2:", v2)
print("Result:", v3)
# Out:
# Vector 1: (3, 4)
# Vector 2: (1, 2)
# Result: (4, 6)

# %% [markdown]
# ## 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


# creating objects
p1 = Person("Aman", 20)
p1.greet()
# Out:
# Hello, my name is Aman and I am 20 years old.

# %% [markdown]
# ## 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # grades should be a list

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


# creating an object
s1 = Student("Riya", [85, 90, 78, 92])

print(f"Average grade of {s1.name}:", s1.average_grade())
# Out:
# Average grade of Riya: 86.25

# %% [markdown]
# ## 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area

# %%
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width


# creating object
r = Rectangle()
r.set_dimensions(5, 10)

print("Area of Rectangle:", r.area())
# Out:
# Area of Rectangle: 50

# %% [markdown]
# ## 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# creating objects
emp = Employee(40, 200)
mgr = Manager(40, 200, 5000)

print("Employee Salary:", emp.calculate_salary())
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 8000
# Manager Salary: 13000

# %% [markdown]
# ## 15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# creating object
p1 = Product("Laptop", 50000, 2)

print("Product Name:", p1.name)
print("Total Price:", p1.total_price())
# Out:
# Product Name: Laptop
# Total Price: 100000

# %% [markdown]
# ## 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method

# %%
from abc import ABC, abstractmethod

class Animal(ABC):  # abstract parent class
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):  # derived class
    def sound(self):
        print("Cow says Moo")


class Sheep(Animal):  # derived class
    def sound(self):
        print("Sheep says Baa")


# creating objects
c = Cow()
s = Sheep()

c.sound()
s.sound()
# Out:
# Cow says Moo
# Sheep says Baa

# %% [markdown]
# ## 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


# creating object
b1 = Book("The Alchemist", "Paulo Coelho", 1988)

print(b1.get_book_info())
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988

# %% [markdown]
# ## 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):  # derived class
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


# creating object of Mansion
m1 = Mansion("Delhi, India", 50000000, 12)

print("Address:", m1.address)
print
# Out:
# Address: Delhi, India
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# ##
